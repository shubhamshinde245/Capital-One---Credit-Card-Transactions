# %% [markdown]
# ## Task 1: Loading the data and providing the basic summary

# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd
import time

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the dataset from json to DataFrame

# %%
df = pd.read_json("transactions.txt", lines=True)
print("Time required to parse data :",time.process_time())
# Out:
# Time required to parse data : 28.265625

# %% [markdown]
# ### Taking a look at first 5 rows

# %%
df.head()
# Out:
#    accountNumber accountOpenDate acqCountry  availableMoney  cardCVV  \
# 0      737265056      2015-03-14         US          5000.0      414
# 1      737265056      2015-03-14         US          5000.0      486
# 2      737265056      2015-03-14         US          5000.0      486
# 3      737265056      2015-03-14         US          5000.0      486
# 4      830329091      2015-08-06         US          5000.0      885
#
#    cardLast4Digits  cardPresent  creditLimit  currentBalance currentExpDate  \
# 0             1803        False         5000             0.0        06/2023
# 1              767         True         5000             0.0        02/2024
# 2              767        False         5000             0.0        08/2025
# 3              767        False         5000             0.0        08/2025
# 4             3143         True         5000             0.0        10/2029
#
#    ...         merchantName merchantState merchantZip  posConditionCode  \
# ...

# %% [markdown]
# ### Taking a look at last 5 rows

# %%
df.tail()
# Out:
#         accountNumber accountOpenDate acqCountry  availableMoney  cardCVV  \
# 786358      732852505      2012-08-23         US        48904.96      936
# 786359      732852505      2012-08-23         US        48785.04      939
# 786360      732852505      2012-08-23         US        48766.15      936
# 786361      732852505      2012-08-23         US        48716.72      939
# 786362      732852505      2012-08-23         US        48666.83      939
#
#         cardLast4Digits  cardPresent  creditLimit  currentBalance  \
# 786358             3783        False        50000         1095.04
# 786359             3388        False        50000         1214.96
# 786360             3783        False        50000         1233.85
# 786361             3388        False        50000         1283.28
# 786362             3388        False        50000         1333.17
#
#        currentExpDate  ...  merchantName merchantState merchantZip  \
# 786358        12/2022  ...          Lyft
# ...

# %% [markdown]
# ### Looking at Information on Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 29 columns):
# accountNumber               786363 non-null int64
# accountOpenDate             786363 non-null object
# acqCountry                  786363 non-null object
# availableMoney              786363 non-null float64
# cardCVV                     786363 non-null int64
# cardLast4Digits             786363 non-null int64
# cardPresent                 786363 non-null bool
# creditLimit                 786363 non-null int64
# currentBalance              786363 non-null float64
# currentExpDate              786363 non-null object
# customerId                  786363 non-null int64
# dateOfLastAddressChange     786363 non-null object
# echoBuffer                  786363 non-null object
# enteredCVV                  786363 non-null int64
# expirationDateKeyInMatch    786363 non-null bool
# isFraud                     786363 non-null bool
# ...

# %% [markdown]
# ## Basic Summary on Data

# %% [markdown]
# #### Number of entries

# %%
print("Number of entries in dataset :",len(df))
# Out:
# Number of entries in dataset : 786363

# %% [markdown]
# #### Number of columns

# %%
print("Number of columns in dataset :",len(df.columns))
# Out:
# Number of columns in dataset : 29

# %% [markdown]
# #### Number of datapoints

# %%
print("Number of datapoints in dataset :",df.count().sum())
# Out:
# Number of datapoints in dataset : 22804527

# %% [markdown]
# #### Number of null values

# %%
print("Number of null values in dataset :",df.isnull().sum())
# Out:
# Number of null values in dataset : accountNumber               0
# accountOpenDate             0
# acqCountry                  0
# availableMoney              0
# cardCVV                     0
# cardLast4Digits             0
# cardPresent                 0
# creditLimit                 0
# currentBalance              0
# currentExpDate              0
# customerId                  0
# dateOfLastAddressChange     0
# echoBuffer                  0
# enteredCVV                  0
# expirationDateKeyInMatch    0
# isFraud                     0
# merchantCategoryCode        0
# merchantCity                0
# merchantCountryCode         0
# merchantName                0
# merchantState               0
# merchantZip                 0
# posConditionCode            0
# posEntryMode                0
# posOnPremises               0
# recurringAuthInd            0
# transactionAmount           0
# transactionDateTime         0
# transactionType             0
# dtype: int64

# %% [markdown]
# ### Checking columns for min max value

# %%
df.min()
# Out:
# accountNumber                         100088067
# accountOpenDate                      1989-08-22
# acqCountry
# availableMoney                         -1005.63
# cardCVV                                     100
# cardLast4Digits                               0
# cardPresent                               False
# creditLimit                                 250
# currentBalance                                0
# currentExpDate                          01/2020
# customerId                            100088067
# dateOfLastAddressChange              1989-08-22
# echoBuffer
# enteredCVV                                    0
# expirationDateKeyInMatch                  False
# isFraud                                   False
# merchantCategoryCode                    airline
# merchantCity
# merchantCountryCode
# merchantName                            1st BBQ
# merchantState
# merchantZip
# posConditionCode
# posEntryMode
# posOnPremises
# recurringAuthInd
# ...

# %%
df.max()
# Out:
# accountNumber                         999389635
# accountOpenDate                      2015-12-31
# acqCountry                                   US
# availableMoney                            50000
# cardCVV                                     998
# cardLast4Digits                            9998
# cardPresent                                True
# creditLimit                               50000
# currentBalance                          47498.8
# currentExpDate                          12/2032
# customerId                            999389635
# dateOfLastAddressChange              2016-12-30
# echoBuffer
# enteredCVV                                  998
# expirationDateKeyInMatch                   True
# isFraud                                    True
# merchantCategoryCode              subscriptions
# merchantCity
# merchantCountryCode                          US
# merchantName                 williamssonoma.com
# merchantState
# merchantZip
# ...

# %% [markdown]
# #### Dropping empty columns

# %%
df.drop(['merchantCity','merchantState','merchantState','merchantZip','posOnPremises','recurringAuthInd'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    accountNumber accountOpenDate acqCountry  availableMoney  cardCVV  \
# 0      737265056      2015-03-14         US          5000.0      414
# 1      737265056      2015-03-14         US          5000.0      486
# 2      737265056      2015-03-14         US          5000.0      486
# 3      737265056      2015-03-14         US          5000.0      486
# 4      830329091      2015-08-06         US          5000.0      885
#
#    cardLast4Digits  cardPresent  creditLimit  currentBalance currentExpDate  \
# 0             1803        False         5000             0.0        06/2023
# 1              767         True         5000             0.0        02/2024
# 2              767        False         5000             0.0        08/2025
# 3              767        False         5000             0.0        08/2025
# 4             3143         True         5000             0.0        10/2029
#
#    ...  expirationDateKeyInMatch isFraud merchantCategoryCode  \
# ...

# %% [markdown]
# #### Checking the data for stastical analysis

# %%
# most useful for availableMoney,creditLimit,currentBalance,transactionAmount
df.describe()
# Out:
#        accountNumber  availableMoney        cardCVV  cardLast4Digits  \
# count   7.863630e+05   786363.000000  786363.000000    786363.000000
# mean    5.372326e+08     6250.725369     544.467338      4757.417799
# std     2.554211e+08     8880.783989     261.524220      2996.583810
# min     1.000881e+08    -1005.630000     100.000000         0.000000
# 25%     3.301333e+08     1077.420000     310.000000      2178.000000
# 50%     5.074561e+08     3184.860000     535.000000      4733.000000
# 75%     7.676200e+08     7500.000000     785.000000      7338.000000
# max     9.993896e+08    50000.000000     998.000000      9998.000000
#
#          creditLimit  currentBalance    customerId     enteredCVV  \
# count  786363.000000   786363.000000  7.863630e+05  786363.000000
# mean    10759.464459     4508.739089  5.372326e+08     544.183857
# std     11636.174890     6457.442068  2.554211e+08     261.551254
# min       250.000000        0.000000  1.000881e+08       0.000000
# ...
